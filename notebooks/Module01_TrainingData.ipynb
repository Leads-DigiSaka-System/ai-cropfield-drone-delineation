# %%
# !pip install rasterio
# !pip install geopandas
# !pip install ultralytics
# Out:
# Requirement already satisfied: rasterio in d:\env\pyagri\lib\site-packages (1.4.3)
# Requirement already satisfied: affine in d:\env\pyagri\lib\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in d:\env\pyagri\lib\site-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in d:\env\pyagri\lib\site-packages (from rasterio) (2025.6.15)
# Requirement already satisfied: click>=4.0 in d:\env\pyagri\lib\site-packages (from rasterio) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in d:\env\pyagri\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in d:\env\pyagri\lib\site-packages (from rasterio) (2.2.5)
# Requirement already satisfied: click-plugins in d:\env\pyagri\lib\site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in d:\env\pyagri\lib\site-packages (from rasterio) (3.2.3)
# Requirement already satisfied: colorama in d:\env\pyagri\lib\site-packages (from click>=4.0->rasterio) (0.4.6)
# Requirement already satisfied: geopandas in d:\env\pyagri\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in d:\env\pyagri\lib\site-packages (from geopandas) (2.2.5)
# Requirement already satisfied: pyogrio>=0.7.2 in d:\env\pyagri\lib\site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in d:\env\pyagri\lib\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=1.4.0 in d:\env\pyagri\lib\site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in d:\env\pyagri\lib\site-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in d:\env\pyagri\lib\site-packages (from geopandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\env\pyagri\lib\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\env\pyagri\lib\site-packages (from pandas>=1.4.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\env\pyagri\lib\site-packages (from pandas>=1.4.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in d:\env\pyagri\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.6.15)
# Requirement already satisfied: six>=1.5 in d:\env\pyagri\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.17.0)
# Requirement already satisfied: ultralytics in d:\env\pyagri\lib\site-packages (8.3.145)
# Requirement already satisfied: numpy>=1.23.0 in d:\env\pyagri\lib\site-packages (from ultralytics) (2.2.5)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\env\pyagri\lib\site-packages (from ultralytics) (3.10.1)
# Requirement already satisfied: opencv-python>=4.6.0 in d:\env\pyagri\lib\site-packages (from ultralytics) (4.11.0)
# Requirement already satisfied: pillow>=7.1.2 in d:\env\pyagri\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\env\pyagri\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in d:\env\pyagri\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in d:\env\pyagri\lib\site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in d:\env\pyagri\lib\site-packages (from ultralytics) (2.5.1)
# Requirement already satisfied: torchvision>=0.9.0 in d:\env\pyagri\lib\site-packages (from ultralytics) (0.20.1)
# Requirement already satisfied: tqdm>=4.64.0 in d:\env\pyagri\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in d:\env\pyagri\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in d:\env\pyagri\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in d:\env\pyagri\lib\site-packages (from ultralytics) (2.2.3)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in d:\env\pyagri\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\env\pyagri\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\env\pyagri\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\env\pyagri\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in d:\env\pyagri\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\env\pyagri\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\env\pyagri\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\env\pyagri\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\env\pyagri\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\env\pyagri\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\env\pyagri\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\env\pyagri\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\env\pyagri\lib\site-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\env\pyagri\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.6.15)
# Requirement already satisfied: filelock in d:\env\pyagri\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\env\pyagri\lib\site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in d:\env\pyagri\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in d:\env\pyagri\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in d:\env\pyagri\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting sympy==1.13.1 (from torch>=1.8.0->ultralytics)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\env\pyagri\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in d:\env\pyagri\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\env\pyagri\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.2 MB 762.0 kB/s eta 0:00:08
#    --- ------------------------------------ 0.5/6.2 MB 762.0 kB/s eta 0:00:08
#    ----- ---------------------------------- 0.8/6.2 MB 817.9 kB/s eta 0:00:07
#    ------ --------------------------------- 1.0/6.2 MB 774.0 kB/s eta 0:00:07
#    ------ --------------------------------- 1.0/6.2 MB 774.0 kB/s eta 0:00:07
#    -------- ------------------------------- 1.3/6.2 MB 789.6 kB/s eta 0:00:07
#    ---------- ----------------------------- 1.6/6.2 MB 798.7 kB/s eta 0:00:06
#    ---------- ----------------------------- 1.6/6.2 MB 798.7 kB/s eta 0:00:06
#    ----------- ---------------------------- 1.8/6.2 MB 751.1 kB/s eta 0:00:06
#    ----------- ---------------------------- 1.8/6.2 MB 751.1 kB/s eta 0:00:06
#    ------------- -------------------------- 2.1/6.2 MB 734.0 kB/s eta 0:00:06
#    ------------- -------------------------- 2.1/6.2 MB 734.0 kB/s eta 0:00:06
#    --------------- ------------------------ 2.4/6.2 MB 729.4 kB/s eta 0:00:06
#    --------------- ------------------------ 2.4/6.2 MB 729.4 kB/s eta 0:00:06
#    ---------------- ----------------------- 2.6/6.2 MB 715.6 kB/s eta 0:00:05
#    ---------------- ----------------------- 2.6/6.2 MB 715.6 kB/s eta 0:00:05
#    ---------------- ----------------------- 2.6/6.2 MB 715.6 kB/s eta 0:00:05
#    ------------------ --------------------- 2.9/6.2 MB 690.4 kB/s eta 0:00:05
#    -------------------- ------------------- 3.1/6.2 MB 709.9 kB/s eta 0:00:05
#    -------------------- ------------------- 3.1/6.2 MB 709.9 kB/s eta 0:00:05
#    ---------------------- ----------------- 3.4/6.2 MB 714.0 kB/s eta 0:00:04
#    ----------------------- ---------------- 3.7/6.2 MB 739.4 kB/s eta 0:00:04
#    ------------------------- -------------- 3.9/6.2 MB 755.3 kB/s eta 0:00:03
#    --------------------------- ------------ 4.2/6.2 MB 755.7 kB/s eta 0:00:03
#    ---------------------------- ----------- 4.5/6.2 MB 773.6 kB/s eta 0:00:03
#    ---------------------------- ----------- 4.5/6.2 MB 773.6 kB/s eta 0:00:03
#    ------------------------------ --------- 4.7/6.2 MB 764.7 kB/s eta 0:00:02
#    ------------------------------ --------- 4.7/6.2 MB 764.7 kB/s eta 0:00:02
#    -------------------------------- ------- 5.0/6.2 MB 772.4 kB/s eta 0:00:02
#    --------------------------------- ------ 5.2/6.2 MB 789.1 kB/s eta 0:00:02
#    ----------------------------------- ---- 5.5/6.2 MB 785.8 kB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.2 MB 785.8 kB/s eta 0:00:01
#    ------------------------------------- -- 5.8/6.2 MB 779.5 kB/s eta 0:00:01
#    ------------------------------------- -- 5.8/6.2 MB 779.5 kB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 783.7 kB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 785.3 kB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: sympy, ultralytics-thop
#
#   Attempting uninstall: sympy
#
#     Found existing installation: sympy 1.14.0
#
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#     Uninstalling sympy-1.14.0:
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#       Successfully uninstalled sympy-1.14.0
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    -------------------- ------------------- 1/2 [ultralytics-thop]
#    -------------------- ------------------- 1/2 [ultralytics-thop]
#    ---------------------------------------- 2/2 [ultralytics-thop]
#
# Successfully installed sympy-1.13.1 ultralytics-thop-2.0.18

# %%
import os, random, shutil, rasterio, torch

import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

from PIL import Image
from tqdm import tqdm

from rasterio.windows import Window
from rasterio.features import shapes
from rasterio.transform import Affine
from shapely.geometry import Polygon, MultiPolygon, box, shape

from ultralytics import YOLO

# %%
def tile_and_label(
    image_path,
    shapefile_path,
    output_image_dir,
    output_label_dir,
    tile_size=256,
    class_id=1
):
    # Load shapefile
    gdf = gpd.read_file(shapefile_path)

    # Open orthophoto
    with rasterio.open(image_path) as src:
        transform = src.transform
        width = src.width
        height = src.height
        crs = src.crs
        gdf = gdf.to_crs(crs)

        os.makedirs(output_image_dir, exist_ok=True)
        os.makedirs(output_label_dir, exist_ok=True)

        tile_id = 0

        for y in tqdm(range(0, height, tile_size), desc="Rows"):
            for x in range(0, width, tile_size):
                window = Window(x, y, tile_size, tile_size)
                transform_tile = src.window_transform(window)

                # Read tile and convert to RGB
                img_tile = src.read([1, 2, 3], window=window)
                img_tile = np.transpose(img_tile, (1, 2, 0))  # HWC
                img_tile = np.clip(img_tile, 0, 255).astype(np.uint8)

                if img_tile.shape[0] == 0 or img_tile.shape[1] == 0:
                    continue

                img_filename = f"tile_{tile_id:05d}.jpg"
                label_filename = f"tile_{tile_id:05d}.txt"
                img_path = os.path.join(output_image_dir, img_filename)
                label_path = os.path.join(output_label_dir, label_filename)

                # Save image tile
                Image.fromarray(img_tile).save(img_path)

                # Create tile bounds in geometry
                tile_bounds = box(*rasterio.windows.bounds(window, transform))

                # Filter polygons that intersect tile
                clipped_gdf = gdf[gdf.intersects(tile_bounds)]
                if clipped_gdf.empty:
                    open(label_path, 'w').close()  # Empty label file
                    tile_id += 1
                    continue

                with open(label_path, 'w') as f:
                    for geom in clipped_gdf.geometry:
                        clipped_geom = geom.intersection(tile_bounds)
                        if clipped_geom.is_empty:
                            continue

                        polygons = [clipped_geom] if isinstance(clipped_geom, Polygon) else clipped_geom.geoms
                        for poly in polygons:
                            coords = list(poly.exterior.coords)
                            norm_coords = []
                            for lon, lat in coords:
                                px, py = (~transform_tile) * (lon, lat)
                                x_norm = px / tile_size
                                y_norm = py / tile_size
                                if 0 <= x_norm <= 1 and 0 <= y_norm <= 1:
                                    norm_coords.append((x_norm, y_norm))

                            if len(norm_coords) < 6:
                                continue  # skip too small polys

                            coords_flat = [str(round(v, 6)) for xy in norm_coords for v in xy]
                            f.write(f"{class_id} {' '.join(coords_flat)}\n")

                tile_id += 1

# %%
tile_and_label(
    image_path="/content/drive/MyDrive/AGRI/Segment/S2DR3/sentinel-2_indices.tif",
    shapefile_path="/content/drive/MyDrive/AGRI/Segment/S2DR3/shp/boundary_CropField_NuevaEcija.shp",
    output_image_dir="/content/drive/MyDrive/AGRI/Segment/S2DR3/images",
    output_label_dir="/content/drive/MyDrive/AGRI/Segment/S2DR3/labels",
    tile_size=256,
    class_id=1
)

# %%
image_dir = '/content/drive/MyDrive/AGRI/Segment/S2DR3/images'
label_dir = '/content/drive/MyDrive/AGRI/Segment/S2DR3/labels'

train_images = '/content/drive/MyDrive/AGRI/Segment/S2DR3/yolo/images/train'
val_images = '/content/drive/MyDrive/AGRI/Segment/S2DR3/yolo/images/val'
train_labels = '/content/drive/MyDrive/AGRI/Segment/S2DR3/yolo/labels/train'
val_labels = '/content/drive/MyDrive/AGRI/Segment/S2DR3/yolo/labels/val'

os.makedirs(train_images, exist_ok=True)
os.makedirs(val_images, exist_ok=True)
os.makedirs(train_labels, exist_ok=True)
os.makedirs(val_labels, exist_ok=True)

files = os.listdir(image_dir)
random.shuffle(files)
split = int(0.8 * len(files))

for f in files[:split]:
    shutil.copy(os.path.join(image_dir, f), train_images)
    shutil.copy(os.path.join(label_dir, f.replace('.jpg', '.txt')), train_labels)

for f in files[split:]:
    shutil.copy(os.path.join(image_dir, f), val_images)
    shutil.copy(os.path.join(label_dir, f.replace('.jpg', '.txt')), val_labels)
